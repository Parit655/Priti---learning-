# %% [markdown]
# <a href="https://colab.research.google.com/github/Parit655/Priti---learning-/blob/main/matplotling1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
x = (1, 2, 3, 4)
y = [10, 20, 15, 25]
plt.plot(x,y)
plt.show ()

# %% [markdown]
# pyplot.py

# %%
import matplotlib.pyplot as plt
x = ['mon', 'tue', 'wed', 'thur', 'fri'] #x-axis
y = [10,15,7,20,12] #y-axis

plt.plot(x,y)

plt.title('Backery sales this week!')

plt.xlabel('day of the week')
plt.ylabel('sales pr day')

plt.show()

# %% [markdown]
# python function.py

# %%
import matplotlib.pyplot as plt

months = [1, 2, 3, 4]
sales = [1000, 1500, 1200, 1800]

# Corrected parameters: 'color', 'linestyle', 'marker'
plt.plot(months, sales, color='orange', linestyle='--', linewidth=2, marker='o', label='2025 sales data')

plt.xlabel('Months')
plt.ylabel('Sales per Month')
plt.title('Monthly Sales Data Report')
plt.legend()  # This line shows the label in
plt.legend(legend='upper left', footsize =12)
plt.grid(colour= 'gray')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-2950894723> in <cell line: 0>()
#      11 plt.title('Monthly Sales Data Report')
#      12 plt.legend()  # This line shows the label in
# ---> 13 plt.legend(legend='upper left', footsize =12)
#      14 plt.grid(colour= 'gray')
#      15 plt.show()
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/pyplot.py in legend(*args, **kwargs)
#    3617 @_copy_docstring_and_deprecators(Axes.legend)
#    3618 def legend(*args, **kwargs) -> Legend:
# -> 3619     return gca().legend(*args, **kwargs)
#    3620
#    3621
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/axes/_axes.py in legend(self, *args, **kwargs)
#     335         """
#     336         handles, labels, kwargs = mlegend._parse_legend_args([self], *args, **kwargs)
# --> 337         self.legend_ = mlegend.Legend(self, handles, labels, **kwargs)
# ...

# %%
import matplotlib.pyplot as plt

months = [1, 2, 3, 4]
sales = [1000, 1500, 1200, 1800]

# Corrected parameters: 'color', 'linestyle', 'marker'
plt.plot(months, sales, color='orange', linestyle='--', linewidth=2, marker='o', label='2025 sales data')

plt.xlabel('Months')
plt.ylabel('Sales per Month')
plt.title('Monthly Sales Data Report')
plt.legend(loc='upper left', fontsize=12)
plt.grid(color='gray', lineStyle=':', linewidth=1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-2332278173> in <cell line: 0>()
#      11 plt.title('Monthly Sales Data Report')
#      12 plt.legend(loc='upper left', fontsize=12)
# ---> 13 plt.grid(color='gray', lineStyle=':', linewidth=1)
#      14 plt.show()
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/pyplot.py in grid(visible, which, axis, **kwargs)
#    3385     **kwargs,
#    3386 ) -> None:
# -> 3387     gca().grid(visible=visible, which=which, axis=axis, **kwargs)
#    3388
#    3389
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/axes/_base.py in grid(self, visible, which, axis, **kwargs)
#    3310         _api.check_in_list(['x', 'y', 'both'], axis=axis)
#    3311         if axis in ['x', 'both']:
# -> 3312             self.xaxis.grid(visible, which=which, **kwargs)
#    3313         if axis in ['y', 'both']:
# ...

# %%
import matplotlib.pyplot as plt

months = [1, 2, 3, 4]
sales = [1000, 1500, 1200, 1800]

# Plotting with correct parameters
plt.plot(months, sales, color='black', linestyle='--', linewidth=2, marker='o', label='2025 sales data')

plt.xlabel('Months')
plt.ylabel('Sales per Month')
plt.title('Monthly Sales Data Report')
plt.legend(loc='upper left', fontsize=12)
plt.grid(color='gray', linestyle=':', linewidth=1)
plt.show()
